# %% [markdown]
# # Crawling data Website Berita CNN
#
# ---

# %% [markdown]
# ## 1. Install modul Beautifulsoup dan requests

# %%
# !pip install requests
# !pip install BeautifulSoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.8/dist-packages (4.6.3)

# %% [markdown]
# ## 2. Import library

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## 3. Peroses crawling menggunakan bs4 dan request

# %%
#Inisialisasi Link URL
url = 'https://www.cnnindonesia.com/olahraga/sepakbola'

headers={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
    }

#inisialisasi list untuk memasukkan hasil crawling kedalam list
listJudul = []
listIsi = []

#proses perulangan untuk crawling data
for page in range(1,4):
  req = requests.get(url+str(page), headers=headers)
  soup = BeautifulSoup(req.text, 'html.parser')
  items = soup.findAll('article')
  for it in items:
    try: link = it.find('a')['href']
    except : link=''
    try: title = it.find('h2', 'title').text 
    except : title=''
    
    if title != '':
      listJudul.append(title)

    if link != '':
      req2 = requests.get(str(link), headers=headers)
      soup2 = BeautifulSoup(req2.text, 'html.parser')
      items2 = soup2.findAll("div", "detail_text")
      for it2 in items2:
        try : berita = it2.find('p').text
        except : berita=''

        if berita != '':
          listIsi.append(berita)


df_Judul = pd.DataFrame(listJudul, columns=["Judul Berita"])
df_Isi = pd.DataFrame(listIsi, columns=["Isi Berita"])

data = pd.concat([df_Judul, df_Isi], axis=1)
data = data.loc[0:50]
data
# Out:
#                                          Judul Berita  \
# 0   Sidang Etik Bharada E di Kasus Pembunuhan Yosu...
# 1   Litbang Kompas: Elektabilitas Ganjar Naik, Ani...
# 2   Komplotan Polisi Gadungan di Ditangkap di Jakb...
# 3   Putin Tangguhkan Pakta Nuklir dengan AS Jelang...
# 4   Belarus Siaga 'Perang' usai Klaim Tentara Ukra...
# 5   PBB Kritik Permukiman Ilegal Israel di Palesti...
# 6   Ericsson Pangkas 1.400 Karyawan di Swedia, PHK...
# 7   Rupiah Lunglai ke Rp15.210 per Dolar Menantika...
# 8      Harga Emas Antam Lesu ke Rp1,019 Juta per Gram
# 9   Dua Kiper Terbaik Kompak Blunder Konyol di Liv...
# 10  Timnas U-20 Panen Pujian dari Pelatih Guatemal...
# 11  STY Gemas Timnas U-20 Rajin Buang Peluang: Sup...
# 12  TikTok Bikin TikTok TV di Indonesia, Apa Istim...
# 13  5 Penyebab Windows 10 Lemot dan Cara Mengatasinya
# 14  CEO IBM Sebut AI bakal Gantikan Banyak Pekerja...
# 15  Belajar Segala Sesuatu soal Kendaraan Elektrif...
# 16  Lexus UX 300e Bekas G20 Jadi Mobil Dinas Pemer...
# 17                     Harga LCGC Bakal Naik 5 Persen
# 18                  Ayah Indy Barends Meninggal Dunia
# 19  Cerita Bintang Teluh Darah Bertemu 'Jung-hwan'...
# 9   Dua kiper top dunia, Thibaut Courtois dan Alis...
# 10  Pelatih Guatemala Rafael Loredo Silva memuji h...
# 11  Shin Tae Yong gemas melihat Timnas Indonesia U...
# 12  TikTok resmi menyediakan TikTok TV di Indonesi...
# 13  Windows 10 lemot saat digunakan bisa disebabka...
# 14  CEO IBM, Arvind Krishna menyebut, kecerdasan b...
# 15  Lexus memastikan mobil listrik mereka, UX 300e...
# 16  Banderol mobil harga terjangkau ramah lingkung...
# 17  Kabar duka datang dari presenter Indy Barends....
# 18  Mikha Tambayong dan Deva Mahenra punya momen b...
# 19  Putra Siregar dan istrinya, Septia Yetri Opani...
# 20  Rabu Abu menandakan awal masa Prapaskah sekali...
# 21  Masa Prapaskah 2023 dimulai pada 22 Februari 2...
# 22  Doa bulan Syaban berikut pernah diajarkan oleh...
# 23  Mabes Polri menggelar sidang Komisi Kode Etik ...
# 24  Gubernur Jawa Tengah (Jateng) Ganjar Pranowo m...
# 25  Polisi menangkap komplotan empat pria yang kar...
# 26  Presiden Rusia Vladimir Putin menangguhkan per...
# 27  Belarus siaga usai mengklaim sekelompok pasuka...
# 28  Dewan Keamanan Perserikatan Bangsa-Bangsa (PBB...
# 29  Perusahaan telekomunikasi dan jaringan, Ericss...
# 30  Nilai tukar rupiah berada di level Rp15.210 pe...
# 31  Harga jual emas PT Aneka Tambang (Persero) Tbk...
# 32  Dua kiper top dunia, Thibaut Courtois dan Alis...
# 33  Pelatih Guatemala Rafael Loredo Silva memuji h...
# 34  Shin Tae Yong gemas melihat Timnas Indonesia U...
# 35  TikTok resmi menyediakan TikTok TV di Indonesi...
# 36  Windows 10 lemot saat digunakan bisa disebabka...
# 37  CEO IBM, Arvind Krishna menyebut, kecerdasan b...
# 38  Lexus memastikan mobil listrik mereka, UX 300e...
# 39  Banderol mobil harga terjangkau ramah lingkung...
# 40  Kabar duka datang dari presenter Indy Barends....
# 41  Mikha Tambayong dan Deva Mahenra punya momen b...
# 42  Putra Siregar dan istrinya, Septia Yetri Opani...
# 43  Rabu Abu menandakan awal masa Prapaskah sekali...
# 44  Masa Prapaskah 2023 dimulai pada 22 Februari 2...
# 45  Doa bulan Syaban berikut pernah diajarkan oleh...
# 46  Mabes Polri menggelar sidang Komisi Kode Etik ...
# 47  Gubernur Jawa Tengah (Jateng) Ganjar Pranowo m...
# 48  Polisi menangkap komplotan empat pria yang kar...
# 49  Presiden Rusia Vladimir Putin menangguhkan per...
# 50  Belarus siaga usai mengklaim sekelompok pasuka...

# %% [markdown]
# ## 4.Export To CSV

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/Prosaindata/CrawlingWebBerita.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  data.to_csv(f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
